# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 236.374
# The Mean absolute error is 12.122

# %% [markdown]
# HW1 data: IBM HR Analytics Employee Attrition & Performance
#
# 1.你選的這組資料為何重要?
# A1: 首先資料裡面有連續型與類別型資料方便日後可做資料轉換練習與預測練習，並且選一組自己比較看得懂且有感的資料。
# 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# A2: 從Kaggle上下載而來:IBM HR Analytics Employee Attrition & Performance
# 3.蒐集而來的資料型態為何
# A3: 包含連續型資料與類別型資料
# 4.這組資料想解決的問題如何評估
# A4: 想藉由員工的metadata評估人員流動率

# %% [markdown]
# HW2 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，
#     請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# A1:主要需要蒐集資訊有: [載客地點]、[下車地點]、[載送時間]、[空車時間]、[乘車人數]
#     想藉由上述資訊得知那些載客地區或地點招車率高，載送距離長或短的影響，乘車人數與搭車距離關係
# 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# A2: 如果GPS有此功能則利用GPS的裝置取得，或者藉由Google Map上取得[載客地點]、[下車地點]，
#     而[載送時間]、[空車時間]、[乘車人數]則用手機連上google sheets另作紀錄。
# 3.蒐集而來的資料型態為何
# A3: [載客地點]、[下車地點] => string，[載送時間]、[空車時間]、[乘車人數] => 以秒表示可用Int
# 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# A4: 透過經緯度資料可以嘗試先看載客地點，載客距離(載客地點->下車地點)與載送時間的關係，
#     找出哪些地點比較容易有生意並且閒置時間較短者，應該就可以達到提升業績目的。
